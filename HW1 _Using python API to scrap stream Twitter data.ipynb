# %%
import tweepy  
consumer_key = "0VMKIP0t4cjjDrZbTznsOT8js"
consumer_secret = "S2J9JcLDFAIeQZpECaW1Uj3R7sCLEP1g9MQRRUmOQDHCHMGtWN"
access_token= "943741648554557440-El1senBtd3ibcsSe11uCogKVr81oyOg"
access_token_secret = "3rBXflkLQQT0H6xWDT1TCSB07sK2RIz7gCtq8RIZkFX15"
# 创建认证对象
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)  
# 设置你的access token和access secret
auth.set_access_token(access_token, access_token_secret)  
# 传入auth参数，创建API对象
api = tweepy.API(auth)

# %%
# 使用API对象获取你的时间轴上的微博，并把结果存在一个叫做public_tweets的变量中
public_tweets = api.home_timeline()  
# 遍历所拉取的全部微博
for tweet in public_tweets:  
   # 打印存在微博对象中的text字段
   print (tweet.text)

# %%
# 传入认证信息，并创建API对象
api = tweepy.API(auth)

# 待拉取微博的用户
name = "lukewalton"  
# 待拉取的微博数量
tweetCount = 50

# 使用上面的参数，调用user_timeline函数
results = api.user_timeline(id=name, count=tweetCount)

# 遍历所拉取的全部微博
for tweet in results:  
   # 打印存在微博对象中的text字段
   print (tweet.text)

# %% [markdown]
# ### 接下来是stream 数据，就是实时监听现在发的twitter

# %%
import datetime
import csv
import tweepy
import json
import simplejson
import pandas as pd
def process_or_store(tweet):
    json.dumps(tweet)

def datetime_handler(x):
    if isinstance(x, datetime.datetime):
        return x.isoformat()
    raise TypeError("Unknown type")

consumer_key = "0VMKIP0t4cjjDrZbTznsOT8js"
consumer_secret = "S2J9JcLDFAIeQZpECaW1Uj3R7sCLEP1g9MQRRUmOQDHCHMGtWN"
access_token= "943741648554557440-El1senBtd3ibcsSe11uCogKVr81oyOg"
access_token_secret = "3rBXflkLQQT0H6xWDT1TCSB07sK2RIz7gCtq8RIZkFX15"
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)  
auth.set_access_token(access_token, access_token_secret)  
api = tweepy.API(auth,wait_on_rate_limit=True)  

language = "en"
query = "lukewalton" 
#csvFile = open('result.csv', 'a')
#csvWriter = csv.writer(csvFile)
for tweet in api.search(q=query,lang=language,count = 100):
    process_or_store(tweet._json)
    print(tweet._json['text'])
#      result.append({
#


#test=pd.read_json('tweet._json',lines=True)
#test
    #process_or_store(tweet._json)
    # Write a row to the CSV file. I use encode UTF-8
    #data = json.loads([tweet.id, tweet.created_at, tweet.text])
    #savefile = open('SB.json','a')
    #savefile.write('\n')
    #json.dump(data,savefile)
    #csvWriter.writerow([tweet.id, tweet.created_at, tweet.text.encode('utf-8')])
   # print (tweet.id, tweet.created_at, tweet.text)
    
#csvFile.close()
# Out:
# RT @0piods_: Why don’t women report it the next fucking day? Like saying it was old n shit makes me think it’s fake #LukeWalton
# Haha love that shit https://t.co/t6VynD1ZNM
# @alistair_aw @DomWalton10 @NicolaWalton8 @luke_lukewalton Happy birthday Quinny
# #ICYMI Sacramento Kings, #NBA begin sex-assault inquiry into coach Luke Walton https://t.co/Tz1queIV5U… https://t.co/bWv4Nm10XZ
# RT @kane_tingle10: Can I have tea in the bottom half of the mug and then coffee in the top half. I started drinking it about 18 months ago,…
# @luke_lukewalton Luke’s had a beer
# @danclark39 Unlike Leeds
# @amehill @alistair_aw @davegrundy_73 @DomWalton10 @NicolaWalton8 @buzzball73 @TrumpTurnberry What have I told you a… https://t.co/xaLcKIOaGp
# @revill73 @nffcbrad Nigerian basketball b team😂
# RT @revill73: @nffcbrad what you betting on tonight geez roulette dogs bingo or snail racing 🤔
# ...

# %% [markdown]
# #This is how we connect python API with MySQL.

# %%
# import pymysql.cursors
# import json
# import tweepy
# import time
# from tweepy import OAuthHandler
# from tweepy import Stream
# from tweepy.streaming import StreamListener

# connection = pymysql.connect(host='localhost',
#                              user='root',
#                              password='19900502Nigmat!',
#                              db= 'testdatabase',
#                              charset='utf8mb4',
#                              cursorclass=pymysql.cursors.DictCursor)


# def WriteToSQL(tweet_id, created_at, screen_name, text, location, favorite):   
#     cursor = connection.cursor()
#     print('error1')

#     sql = "INSERT INTO dynamicdata (`TwitterID`, `Data`,`Text`,`Location`,`ScreenName`,`Favorited`) VALUES (%s, %s, %s, %s, %s, %s)"
   
#     print('error2')

#     cursor.execute(sql, (tweet_id, created_at, text, location, screen_name, favorite))
#     print('error3')
#     connection.commit()



# class listener(StreamListener):

#     def on_data(self, data):

#         jsondata = json.loads(data)
#         tweet_id = jsondata['id']
#         created_at = jsondata['created_at']
#         screen_name = jsondata['user']['screen_name']
#         text = jsondata['text']
#         location = jsondata['user']['location']
#         favorite = jsondata['user']['favourites_count']

#         WriteToSQL(tweet_id, created_at, screen_name, text, location, favorite)
#         return True
#     def on_error(self, status):
#         print(status)

# consumer_key = "0VMKIP0t4cjjDrZbTznsOT8js"
# consumer_secret = "S2J9JcLDFAIeQZpECaW1Uj3R7sCLEP1g9MQRRUmOQDHCHMGtWN"
# access_token= "943741648554557440-El1senBtd3ibcsSe11uCogKVr81oyOg"
# access_token_secret = "3rBXflkLQQT0H6xWDT1TCSB07sK2RIz7gCtq8RIZkFX15"

# auth = tweepy.OAuthHandler(consumer_key, consumer_secret)  

# auth.set_access_token(access_token, access_token_secret)  

# twitterStream = Stream(auth, listener(),tweet_mode = 'extended')

# twitterStream.filter(track=['#hiking','#diving','#cycling','#skiing','#surfing','#boating','#camping','#fising','#backpacking','#hunting'])

# %%
print('222')
# Out:
# 222

# %%
import pymysql.cursors
import json
import tweepy
import time
from tweepy import OAuthHandler
from tweepy import Stream
from tweepy.streaming import StreamListener

connection = pymysql.connect(host='localhost',
                             user='root',
                             password='19900502Nigmat!',
                             db= 'NBA',
                             charset='utf8mb4',
                             cursorclass=pymysql.cursors.DictCursor)

#def WriteToSQL(tweet_id, created_at, screen_name, text, location, favorite, retweet):
def WriteToSQL(tweet_id, created_at, screen_name, text, location, favorite):   
    cursor = connection.cursor()

    #sql = "INSERT INTO dynamicdata (`TwitterID`, `Data`,`Text`,`Location`,`ScreenName`,`Favorited`,`Retweets`) VALUES (%s, %s, %s, %s, %s, %s, %s)"
   # try:
    sql = "INSERT INTO coach(`TwitterID`, `Date`,`Text`,`Location`,`ScreenName`,`Favorited`) VALUES (%s, %s, %s, %s, %s, %s)"
   
   # print ("erro1")
   # cursor.execute(sql, (tweet_id, created_at, text, location, screen_name, favorite, retweet))
    cursor.execute(sql, (tweet_id, created_at, text, location, screen_name, favorite))
    print('ok')
    connection.commit()
  #  except:
    #print ("Error")


class listener(StreamListener):

    def on_data(self, data):

        jsondata = json.loads(data)
        tweet_id = jsondata['id']
        created_at = jsondata['created_at']
        screen_name = jsondata['user']['screen_name']
        text = jsondata['text']
        location = jsondata['user']['location']
        favorite = jsondata['user']['favourites_count']
        #hashtags = [hashtag['text'] for hashtag in tweet['entities']['hashtags']]
        #retweet = jsondata['entities']['hashtags'][0]
        #retweet = json.dumps(jsondata['entities']['hashtags'])
        
        
       # WriteToSQL(tweet_id, created_at, screen_name, text, location, favorite, retweet)
        WriteToSQL(tweet_id, created_at, screen_name, text, location, favorite)
        return True
    def on_error(self, status):
        print(status)

consumer_key = "0VMKIP0t4cjjDrZbTznsOT8js"
consumer_secret = "S2J9JcLDFAIeQZpECaW1Uj3R7sCLEP1g9MQRRUmOQDHCHMGtWN"
access_token= "943741648554557440-El1senBtd3ibcsSe11uCogKVr81oyOg"
access_token_secret = "3rBXflkLQQT0H6xWDT1TCSB07sK2RIz7gCtq8RIZkFX15"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)  

auth.set_access_token(access_token, access_token_secret)  

twitterStream = Stream(auth, listener(),tweet_mode = 'extended')
## twitterStream.filter(track=['flight travel','road trip','RV trip','Cruise','greyhound','rail travel','train travel','drive travel','shuttle travel','bike travel','bus travel','coach travel','ferry travel','motocycle travel','fly travel'])

#twitterStream.filter(track=['zelda', 'pubg'])
#twitterStream.filter(track=['#Celtics', '#Lakers','#Warriors','#Rocket','#Clippers','#76ers','#Pacers','#Thunder','#Pistons','#UtahJazz'])
twitterStream.filter(track=['bradstevens', 'lukewalton','stevekerr','mikeantoni','docrivers','brettbrown','natemcnillan','billydonovan','dwanecasey','quinsnyder'])
# Out:
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok

# %%
1
